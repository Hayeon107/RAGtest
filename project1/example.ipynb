# %%
# %pip install openai langchain faiss-cpu python-dotenv
# %pip install tiktoken  # 토큰 수 계산용
# %pip install PyPDF2  # PDF, 문서 파싱용
# Out:
# Requirement already satisfied: openai in c:\RAGtest\RAGtest\venv\Lib\site-packages (2.36.0)
# Requirement already satisfied: langchain in c:\RAGtest\RAGtest\venv\Lib\site-packages (1.2.18)
# Requirement already satisfied: faiss-cpu in c:\RAGtest\RAGtest\venv\Lib\site-packages (1.13.2)
# Requirement already satisfied: python-dotenv in c:\RAGtest\RAGtest\venv\Lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from openai) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in c:\RAGtest\RAGtest\venv\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.14)
# Requirement already satisfied: certifi in c:\RAGtest\RAGtest\venv\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\RAGtest\RAGtest\venv\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.3 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.10 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langchain) (1.1.10)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.8.3)
# Requirement already satisfied: packaging>=23.2.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.3->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (4.0.3)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.12 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (1.0.13)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (2.34.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (0.25.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from faiss-cpu) (2.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\RAGtest\RAGtest\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (2.7.0)
# Requirement already satisfied: colorama in c:\RAGtest\RAGtest\venv\Lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^

# %%
from PyPDF2 import PdfReader

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OpenAIEmbeddings
from PyPDF2 import PdfReader

# %%
reader = PdfReader("kgscodeFP216.pdf")
texts = [page.extract_text() for page in reader.pages]

# %%
print(texts[10])
# Out:
#     3.3.7 피해저감설비 점검· · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 2
#     3.3.8 부대설비 점검· · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 2
#   3.4 수리ᆞ청소 및 철거기준 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 2
#     3.4.1 수리ᆞ청소 및 철거준비 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 2
#     3.4.2 수리ᆞ청소 및 철거 작업· · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 3
#     3.4.3 수리ᆞ청소 및 철거 사후 조치· · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 4
# 3.5 그 밖의 기준· · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 4
# 4. 검사기준 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 5
#   4.1 검사항목 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 5
#     4.1.1 중간검사 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 5
#     4.1.2 완성검사 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 5
#     4.1.3 정기검사 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 6
#     4.1.4 수시검사 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 7
#   4.2 검사방법 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 7
#     4.2.1 중간검사 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 9 7
#     4.2.2 완성검사 및 정기검사 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 100
# 부록 A 수소연료 충전시설의 충전 안전성능 확인평가 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 105
# 부록 B 프리캐스트 콘크리트 부재의 성능인증 · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · · 114
